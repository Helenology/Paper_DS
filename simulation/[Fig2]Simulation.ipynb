# %%
# import cv2 as cv
import sys
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
from keras.utils import array_to_img
import tensorflow_probability as tfp
from tensorflow.keras.layers import AveragePooling2D

sys.path.append("../models/GPA")
sys.path.append("../models/CD")
sys.path.append("../models/DS/")
sys.path.append("../")
from gpa import GPA
from cd import CD
from ds import DS

from utils import *
from simu_auxiliary import *
# Out:
# 2025-10-13 08:23:24.977340: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-13 08:23:25.041892: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-13 08:23:25.898543: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 1 Physical GPUs, 1 Logical GPUs
# 2025-10-13 08:23:28.033327: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22177 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:31:00.0, compute capability: 8.9

# %% [markdown]
# ## Hyper-parameters

# %%
T = 100                    # the number of replications
N_list = [100, 500, 1000]  # the number of images
p = 540                    # image height
q = 960                    # image width
M = p * q                  # the number of pixel locations
G = 500                    # the number of grid points
test_size = 100            # the number of test images
filter_size = 3            # filter size for kernel smoothing

# %% [markdown]
# ## Distribution

# %%
# standard deviation & mean
sigma = 0.04158134 ** (0.5)  # standard deviation
avg_pool_2d_mean = AveragePooling2D(pool_size=(5, 5), strides=1, padding="same")
mean = np.load('./mean-540.npy').reshape([1, p, q, 1])  # mean
mean = tf.reshape(avg_pool_2d_mean(mean), (1, p, q))    # smoothed mean
# Out:
# 2025-10-13 08:23:45.203816: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8900

# %%
# grid points: randomly generated from U[0, 1]
np.random.seed(0)
tf.random.set_seed(0)
tick_list = np.random.uniform(size=G)
grid_point = tf.concat([tf.ones([1, p, q]) * tick for tick in tick_list], axis=0)

# oracle distribution
tfd = tfp.distributions
dist = tfd.TruncatedNormal(loc=mean, scale=sigma, low=[0.], high=[1.])

# %% [markdown]
# ## Run Experiments
#
# - Abbreviations:
#     - CD: Classical nonparametric Density
#     - DS: Doubly Smoothed
#     - GPA: Grid Point Approximation

# %%
experiment_stats = {"N": [],            # sample size
                    "t": [],            # id of the replication
                    "CD_mse": [],       # MSE of the CD method
                    "DS_mse": [],       # MSE of the DS method
                    "GPA_CD_mse": [],   # MSE of the GPA-CD method
                    "GPA_DS_mse": [],   # MSE of the GPA-DS method
                    "CD_time": [],      # computation time of the CD method
                    "DS_time": [],      # computation time of the DS method
                    "GPA_CD_time": [],  # computation time of the GPA-CD method
                    "GPA_DS_time": []}  # computation time of the GPA-DS method

# %%
# == Main experiment loop ==
# -- Assumption: `test_imgs` and `test_orcs` are precomputed outside (above chunk),
# -- so every method, N (sample size), and t (replication index) is evaluated
# -- on the SAME test set for fair comparison.
for N in N_list:
    print(f"====================== N={N} ======================")
    # -- Change path as you needed
    path = f'../../../[simu]train_img(N={N})/'  # Directory to save N simulated images
    bandwidth, bandwidth_star = compute_optimal_bandwidths(N, M, sigma)  # (rule-of-thumb) bandwidths
    location_filter = get_location_filter(p, q, bandwidth, filter_size)
    
    # == Replicate loop (T times) ==
    # -- Different training sets per replicate
    for t in range(T):
        print(f"======== N={N}: The {t}-th replication ========")
        # -- Set seeds so all methods within the same replicate share training randomness
        seed = N + t
        tf.random.set_seed(seed)
        np.random.seed(seed)
        
        # -- Initialize cumulative metrics
        CD_mse = 0.0
        DS_mse = 0.0
        GPA_CD_mse = 0.0
        GPA_DS_mse = 0.0
        CD_time = 0.0
        DS_time = 0.0
        GPA_CD_time = 0.0
        GPA_DS_time = 0.0
        
        # -- Generate the training set for this replicate
        train_list = generate_simulate_data(path, N, mean, sigma)
        
        # -- Build models once per replicate
        CD_model = CD(p, q, train_list)
        ### --- this will fit DS model from raw
        # DS_model = DS(p, q, train_list) 
        ### --- this will fit GPA-CD model from raw
        # GPA_CD_model = GPA(G, p, q, train_list, second_smooth=False, gpa_matrix=None,
        #                    grid_point=grid_point, h=bandwidth, h_star=bandwidth_star, filter_size=None)
        ### --- this will fit GPA-DS model from raw
        # GPA_DS_model = GPA(G, p, q, train_list, second_smooth=True, gpa_matrix=None,
        #                    grid_point=grid_point, h=bandwidth, h_star=bandwidth_star, filter_size=filter_size)
        ### --- the below computation of GPA-DS is computed based on GPA-CD, which will save time
        ### --- this is because GPA_DS_model = GPA(xxx) will rerun the GPA-CD computation and then doubly smooth
        GPA_CD_matrix = compute_CD_matrix(path, N, G, p, q, bandwidth, grid_point)
        Omega1 = tf.nn.depthwise_conv2d(tf.reshape(GPA_CD_matrix, [G, p, q, 1]), 
                                        location_filter, strides=[1, 1, 1, 1], padding='SAME')
        Omega2 = tf.reduce_sum(location_filter)
        GPA_DS_matrix = Omega1 / Omega2
        GPA_CD_matrix = tf.squeeze(GPA_CD_matrix)
        GPA_DS_matrix = tf.squeeze(GPA_DS_matrix)
        ### --- Fit the model based on pre-computed GPA matrix
        GPA_CD_model = GPA(G, p, q, train_list, second_smooth=False, gpa_matrix=GPA_CD_matrix,
                           grid_point=grid_point, h=bandwidth, h_star=bandwidth_star, filter_size=None)
        GPA_DS_model = GPA(G, p, q, train_list, second_smooth=True, gpa_matrix=GPA_DS_matrix, 
                           grid_point=grid_point, h=bandwidth, h_star=bandwidth_star, filter_size=filter_size)
        
        # == Evaluate four methods on the test set ==
        for test_i in range(test_size):
            # -- The test image and its oracle density
            test_img = tf.ones([p, q]) * np.random.uniform()
            test_orc = tf.squeeze(dist.prob(test_img))
            
            # -- CD 
            t1 = time.time()
            CD_test = CD_model.CD_estimation(test_img, bandwidth)
            t2 = time.time()
            CD_time += t2 - t1
            
            # -- DS 
            t3 = time.time()
            # DS_test = DS_model.DS_estimation(test_img, bandwidth, size=filter_size)
            CD_test = tf.reshape(CD_test, (1, p, q))
            DS_test = compute_DS_matrix(CD_test, location_filter)
            t4 = time.time()
            DS_time += t2 - t1 + t4 - t3
            
            # -- GPA-CD 
            t1 = time.time()
            GPA_CD_test = GPA_CD_model.compute_density(test_img)
            t2 = time.time()
            GPA_CD_time += t2 - t1
            
            # -- GPA-DS 
            t1 = time.time()
            GPA_DS_test = GPA_DS_model.compute_density(test_img)
            t2 = time.time()
            GPA_DS_time += t2 - t1

            # -- Accumulate MSE; average over test_size after the loop
            CD_mse     += MSE(test_orc, tf.squeeze(CD_test))
            DS_mse     += MSE(test_orc, tf.squeeze(DS_test)) 
            GPA_CD_mse += MSE(test_orc, tf.squeeze(GPA_CD_test))
            GPA_DS_mse += MSE(test_orc, tf.squeeze(GPA_DS_test)) 
        
        # -- Average metrics for this replicate (divide by test_size)
        experiment_stats["N"].append(N)
        experiment_stats["t"].append(t)
        experiment_stats["CD_mse"].append(CD_mse.numpy() / test_size)
        experiment_stats["DS_mse"].append(DS_mse.numpy() / test_size)
        experiment_stats["GPA_CD_mse"].append(GPA_CD_mse.numpy() / test_size)
        experiment_stats["GPA_DS_mse"].append(GPA_DS_mse.numpy() / test_size)
        experiment_stats["CD_time"].append(CD_time / test_size)
        experiment_stats["DS_time"].append(DS_time / test_size)
        experiment_stats["GPA_CD_time"].append(GPA_CD_time / test_size)
        experiment_stats["GPA_DS_time"].append(GPA_DS_time / test_size)
        
        # -- Timely record the results
        experiment_stats_csv = pd.DataFrame(experiment_stats)
        experiment_stats_csv.to_csv(f'./results/simulation.csv', index=False)
# Out:
# ====================== N=100 ======================
# Optimal bandwidth from Rule of Thumb: 0.021559220187773835
# Optimal bandwidth* from GPA estimation: 0.0023239998755245745
# ======== N=100: The 0-th replication ========
# ======== N=100: The 1-th replication ========
# ======== N=100: The 2-th replication ========
# ======== N=100: The 3-th replication ========
# ======== N=100: The 4-th replication ========
# ======== N=100: The 5-th replication ========
# ======== N=100: The 6-th replication ========
# ======== N=100: The 7-th replication ========
# ======== N=100: The 8-th replication ========
# ======== N=100: The 9-th replication ========
# ======== N=100: The 10-th replication ========
# ======== N=100: The 11-th replication ========
# ======== N=100: The 12-th replication ========
# ======== N=100: The 13-th replication ========
# ======== N=100: The 14-th replication ========
# ======== N=100: The 15-th replication ========
# ======== N=100: The 16-th replication ========
# ======== N=100: The 17-th replication ========
# ======== N=100: The 18-th replication ========
# ======== N=100: The 19-th replication ========
# ======== N=100: The 20-th replication ========
# ======== N=100: The 21-th replication ========
# ======== N=100: The 22-th replication ========
# ======== N=100: The 23-th replication ========
# ======== N=100: The 24-th replication ========
# ======== N=100: The 25-th replication ========
# ======== N=100: The 26-th replication ========
# ======== N=100: The 27-th replication ========
# ======== N=100: The 28-th replication ========
# ======== N=100: The 29-th replication ========
# ======== N=100: The 30-th replication ========
# ======== N=100: The 31-th replication ========
# ======== N=100: The 32-th replication ========
# ======== N=100: The 33-th replication ========
# ======== N=100: The 34-th replication ========
# ======== N=100: The 35-th replication ========
# ======== N=100: The 36-th replication ========
# ======== N=100: The 37-th replication ========
# ======== N=100: The 38-th replication ========
# ======== N=100: The 39-th replication ========
# ======== N=100: The 40-th replication ========
# ======== N=100: The 41-th replication ========
# ======== N=100: The 42-th replication ========
# ======== N=100: The 43-th replication ========
# ======== N=100: The 44-th replication ========
# ======== N=100: The 45-th replication ========
# ======== N=100: The 46-th replication ========
# ======== N=100: The 47-th replication ========
# ======== N=100: The 48-th replication ========
# ======== N=100: The 49-th replication ========
# ======== N=100: The 50-th replication ========
# ======== N=100: The 51-th replication ========
# ======== N=100: The 52-th replication ========
# ======== N=100: The 53-th replication ========
# ======== N=100: The 54-th replication ========
# ======== N=100: The 55-th replication ========
# ======== N=100: The 56-th replication ========
# ======== N=100: The 57-th replication ========
# ======== N=100: The 58-th replication ========
# ======== N=100: The 59-th replication ========
# ======== N=100: The 60-th replication ========
# ======== N=100: The 61-th replication ========
# ======== N=100: The 62-th replication ========
# ======== N=100: The 63-th replication ========
# ======== N=100: The 64-th replication ========
# ======== N=100: The 65-th replication ========
# ======== N=100: The 66-th replication ========
# ======== N=100: The 67-th replication ========
# ======== N=100: The 68-th replication ========
# ======== N=100: The 69-th replication ========
# ======== N=100: The 70-th replication ========
# ======== N=100: The 71-th replication ========
# ======== N=100: The 72-th replication ========
# ======== N=100: The 73-th replication ========
# ======== N=100: The 74-th replication ========
# ======== N=100: The 75-th replication ========
# ======== N=100: The 76-th replication ========
# ======== N=100: The 77-th replication ========
# ======== N=100: The 78-th replication ========
# ======== N=100: The 79-th replication ========
# ======== N=100: The 80-th replication ========
# ======== N=100: The 81-th replication ========
# ======== N=100: The 82-th replication ========
# ======== N=100: The 83-th replication ========
# ======== N=100: The 84-th replication ========
# ======== N=100: The 85-th replication ========
# ======== N=100: The 86-th replication ========
# ======== N=100: The 87-th replication ========
# ======== N=100: The 88-th replication ========
# ======== N=100: The 89-th replication ========
# ======== N=100: The 90-th replication ========
# ======== N=100: The 91-th replication ========
# ======== N=100: The 92-th replication ========
# ======== N=100: The 93-th replication ========
# ======== N=100: The 94-th replication ========
# ======== N=100: The 95-th replication ========
# ======== N=100: The 96-th replication ========
# ======== N=100: The 97-th replication ========
# ======== N=100: The 98-th replication ========
# ======== N=100: The 99-th replication ========
# ====================== N=500 ======================
# Optimal bandwidth from Rule of Thumb: 0.01713090040860087
# Optimal bandwidth* from GPA estimation: 0.001467338744047007
# ======== N=500: The 0-th replication ========
# ======== N=500: The 1-th replication ========
# ======== N=500: The 2-th replication ========
# ======== N=500: The 3-th replication ========
# ======== N=500: The 4-th replication ========
# ======== N=500: The 5-th replication ========
# ======== N=500: The 6-th replication ========
# ======== N=500: The 7-th replication ========
# ======== N=500: The 8-th replication ========
# ======== N=500: The 9-th replication ========
# ======== N=500: The 11-th replication ========
# ======== N=500: The 12-th replication ========
# ======== N=500: The 13-th replication ========
# ======== N=500: The 14-th replication ========
# ======== N=500: The 15-th replication ========
# ======== N=500: The 16-th replication ========
# ======== N=500: The 17-th replication ========
# ======== N=500: The 19-th replication ========
# ======== N=500: The 20-th replication ========
# ======== N=500: The 21-th replication ========
# ======== N=500: The 22-th replication ========
# ======== N=500: The 23-th replication ========
# ======== N=500: The 24-th replication ========
# ======== N=500: The 25-th replication ========
# ======== N=500: The 26-th replication ========
# ======== N=500: The 27-th replication ========
# ======== N=500: The 28-th replication ========
# ======== N=500: The 29-th replication ========
# ======== N=500: The 30-th replication ========
# ======== N=500: The 31-th replication ========
# ======== N=500: The 32-th replication ========
# ======== N=500: The 33-th replication ========
# ======== N=500: The 34-th replication ========
# ======== N=500: The 35-th replication ========
# ======== N=500: The 36-th replication ========
# ======== N=500: The 37-th replication ========
# ======== N=500: The 38-th replication ========
# ======== N=500: The 39-th replication ========
# ======== N=500: The 40-th replication ========
# ======== N=500: The 41-th replication ========
# ======== N=500: The 42-th replication ========
# ======== N=500: The 43-th replication ========
# ======== N=500: The 44-th replication ========
# ======== N=500: The 45-th replication ========
# ======== N=500: The 46-th replication ========
# ======== N=500: The 47-th replication ========
# ======== N=500: The 48-th replication ========
# ======== N=500: The 49-th replication ========
# ======== N=500: The 50-th replication ========
# ======== N=500: The 51-th replication ========
# ======== N=500: The 52-th replication ========
# ======== N=500: The 53-th replication ========
# ======== N=500: The 54-th replication ========
# ======== N=500: The 55-th replication ========
# ======== N=500: The 56-th replication ========
# ======== N=500: The 57-th replication ========
# ======== N=500: The 58-th replication ========
# ======== N=500: The 59-th replication ========
# ======== N=500: The 60-th replication ========
# ======== N=500: The 61-th replication ========
# ======== N=500: The 62-th replication ========
# ======== N=500: The 63-th replication ========
# ======== N=500: The 64-th replication ========
# ======== N=500: The 66-th replication ========
# ======== N=500: The 67-th replication ========
# ======== N=500: The 68-th replication ========
# ======== N=500: The 69-th replication ========
# ======== N=500: The 70-th replication ========
# ======== N=500: The 71-th replication ========
# ======== N=500: The 72-th replication ========
# ======== N=500: The 73-th replication ========
# ======== N=500: The 74-th replication ========
# ======== N=500: The 75-th replication ========
# ======== N=500: The 76-th replication ========
# ======== N=500: The 77-th replication ========
# ======== N=500: The 78-th replication ========
# ======== N=500: The 79-th replication ========
# ======== N=500: The 80-th replication ========
# ======== N=500: The 81-th replication ========
# ======== N=500: The 82-th replication ========
# ======== N=500: The 83-th replication ========
# ======== N=500: The 84-th replication ========
# ======== N=500: The 85-th replication ========
# ======== N=500: The 86-th replication ========
# ======== N=500: The 87-th replication ========
# ======== N=500: The 88-th replication ========
# ======== N=500: The 89-th replication ========
# ======== N=500: The 90-th replication ========
# ======== N=500: The 91-th replication ========
# ======== N=500: The 92-th replication ========
# ======== N=500: The 93-th replication ========
# ======== N=500: The 94-th replication ========
# ======== N=500: The 95-th replication ========
# ======== N=500: The 96-th replication ========
# ======== N=500: The 97-th replication ========
# ======== N=500: The 98-th replication ========
# ======== N=500: The 99-th replication ========
# ====================== N=1000 ======================
# Optimal bandwidth from Rule of Thumb: 0.015515861890218035
# Optimal bandwidth* from GPA estimation: 0.0012037098509816019
# ======== N=1000: The 0-th replication ========
# ======== N=1000: The 1-th replication ========
# ======== N=1000: The 2-th replication ========
# ======== N=1000: The 3-th replication ========
# ======== N=1000: The 4-th replication ========
# ======== N=1000: The 5-th replication ========
# ======== N=1000: The 6-th replication ========
# ======== N=1000: The 7-th replication ========
# ======== N=1000: The 8-th replication ========
# ======== N=1000: The 9-th replication ========
# ======== N=1000: The 10-th replication ========
# ======== N=1000: The 11-th replication ========
# ======== N=1000: The 12-th replication ========
# ======== N=1000: The 13-th replication ========
# ======== N=1000: The 14-th replication ========
# ======== N=1000: The 15-th replication ========
# ======== N=1000: The 16-th replication ========
# ======== N=1000: The 17-th replication ========
# ======== N=1000: The 18-th replication ========
# ======== N=1000: The 19-th replication ========
# ======== N=1000: The 20-th replication ========
# ======== N=1000: The 21-th replication ========
# ======== N=1000: The 22-th replication ========
# ======== N=1000: The 23-th replication ========
# ======== N=1000: The 24-th replication ========
# ======== N=1000: The 25-th replication ========
# ======== N=1000: The 26-th replication ========
# ======== N=1000: The 27-th replication ========
# ======== N=1000: The 29-th replication ========
# ======== N=1000: The 30-th replication ========
# ======== N=1000: The 31-th replication ========
# ======== N=1000: The 32-th replication ========
# ======== N=1000: The 33-th replication ========
# ======== N=1000: The 34-th replication ========
# ======== N=1000: The 35-th replication ========
# ======== N=1000: The 36-th replication ========
# ======== N=1000: The 37-th replication ========
# ======== N=1000: The 38-th replication ========
# ======== N=1000: The 39-th replication ========
# ======== N=1000: The 40-th replication ========
# ======== N=1000: The 41-th replication ========
# ======== N=1000: The 42-th replication ========
# ======== N=1000: The 43-th replication ========
# ======== N=1000: The 44-th replication ========
# ======== N=1000: The 45-th replication ========
# ======== N=1000: The 46-th replication ========
# ======== N=1000: The 47-th replication ========
# ======== N=1000: The 48-th replication ========
# ======== N=1000: The 49-th replication ========
# ======== N=1000: The 50-th replication ========
# ======== N=1000: The 51-th replication ========
# ======== N=1000: The 52-th replication ========
# ======== N=1000: The 53-th replication ========
# ======== N=1000: The 54-th replication ========
# ======== N=1000: The 55-th replication ========
# ======== N=1000: The 56-th replication ========
# ======== N=1000: The 57-th replication ========
# ======== N=1000: The 58-th replication ========
# ======== N=1000: The 59-th replication ========
# ======== N=1000: The 60-th replication ========
# ======== N=1000: The 61-th replication ========
# ======== N=1000: The 62-th replication ========
# ======== N=1000: The 63-th replication ========
# ======== N=1000: The 64-th replication ========
# ======== N=1000: The 65-th replication ========
# ======== N=1000: The 66-th replication ========
# ======== N=1000: The 67-th replication ========
# ======== N=1000: The 68-th replication ========
# ======== N=1000: The 69-th replication ========
# ======== N=1000: The 70-th replication ========
# ======== N=1000: The 71-th replication ========
# ======== N=1000: The 72-th replication ========
# ======== N=1000: The 73-th replication ========
# ======== N=1000: The 74-th replication ========
# ======== N=1000: The 75-th replication ========
# ======== N=1000: The 76-th replication ========
# ======== N=1000: The 77-th replication ========
# ======== N=1000: The 78-th replication ========
# ======== N=1000: The 79-th replication ========
# ======== N=1000: The 80-th replication ========
# ======== N=1000: The 81-th replication ========
# ======== N=1000: The 82-th replication ========
# ======== N=1000: The 83-th replication ========
# ======== N=1000: The 84-th replication ========
# ======== N=1000: The 85-th replication ========
# ======== N=1000: The 86-th replication ========
# ======== N=1000: The 87-th replication ========
# ======== N=1000: The 88-th replication ========
# ======== N=1000: The 89-th replication ========
# ======== N=1000: The 90-th replication ========
# ======== N=1000: The 91-th replication ========
# ======== N=1000: The 92-th replication ========
# ======== N=1000: The 93-th replication ========
# ======== N=1000: The 94-th replication ========
# ======== N=1000: The 95-th replication ========
# ======== N=1000: The 96-th replication ========
# ======== N=1000: The 97-th replication ========
# ======== N=1000: The 98-th replication ========
# ======== N=1000: The 99-th replication ========
